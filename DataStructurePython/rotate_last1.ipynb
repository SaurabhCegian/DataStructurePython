# %%
t = int(input())
while t > 0:
  n = int(input())
  arr = list(map(int, input().split()))
  arr = arr[-1:-2] + arr[-2:0] 
  for var in arr:
    print(var, end=" ")
  t = t-1
# Out:
# 1
# 5
# 1 2 3 4 5

# %%
arr = [1, 2, 3, 4, 5]
temp = arr[]
# Out:
# [5, 2, 3, 4, 1]
