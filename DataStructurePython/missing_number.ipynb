# %%
def getMissingNo(A):
    n = len(A)
    total = (n + 1)*(n + 2)/2
    sum_of_A = sum(A)
    return total - sum_of_A

t = int(input())
while t > 0:
    n = int(input())
    arr = list(map(int, input().split()))
    miss = getMissingNo(arr)
    print(int(miss))
    t = t -1
# Out:
# 2
# 5
# 1 2 3 5
# 4
# 10
# 1 2 3 4 5 6 7 8 10
# 9
